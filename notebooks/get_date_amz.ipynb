# %%
import os
from simplecube import cube_query, simple_cube, cube_get_data

# %%
path_dir = os.path.abspath("")

# %%
datacube=cube_query(
    collection="AMZ1-WFI-L4-SR-1",
    start_date="2024-06-01",
    end_date="2025-05-31",    
    bbox="-52.4048,-24.6221,-51.8005,-24.2169",
    bands=["BAND3","BAND4","CMASK"]
)

# %%
#cube_get_data(datacube)

# %%
cube = simple_cube(
    data_dir=os.path.join(path_dir),
    datacube=datacube,
    source='bdc-amz',
    band='BAND4'
)

cube
# Out:
# <xarray.Dataset> Size: 6GB
# Dimensions:      (band: 1, x: 17888, y: 14388, time: 6)
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 143kB 9.734e+04 9.741e+04 ... 1.242e+06 1.242e+06
#   * y            (y) float64 115kB 6.907e+06 6.907e+06 ... 7.827e+06 7.827e+06
#   * time         (time) datetime64[ns] 48B 2024-06-11 2024-06-14 ... 2024-07-01
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (time, band, y, x) float32 6GB nan nan nan nan ... nan nan nan

# %%
cube_2d = cube['band_data'].sel(time='2024-06-11')

cube_2d.plot()
# Out:
# /home/sansigolo/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
