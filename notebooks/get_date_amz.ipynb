# %%
import os
from simplecube import cube_query, simple_cube, cube_get_data

# %%
path_dir = os.path.abspath("")

# %%
datacube=cube_query(
    collection="AMZ1-WFI-L4-SR-1",
    start_date="2024-06-01",
    end_date="2025-05-31",    
    bbox="-52.4048,-24.6221,-51.8005,-24.2169",
    bands=["BAND3","BAND4"]
)

# %%
#cube_get_data(datacube)

# %%
cube = simple_cube(
    data_dir=os.path.join(path_dir),
    datacube=datacube,
    source='bdc-amz',
    band='BAND4'
)

cube
# Out:
# <xarray.Dataset> Size: 262MB
# Dimensions:      (band: 1, x: 963, y: 709, time: 96)
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 8kB 3.574e+05 3.574e+05 ... 4.189e+05 4.189e+05
#   * y            (y) float64 6kB 7.322e+06 7.321e+06 ... 7.276e+06 7.276e+06
#     spatial_ref  int64 8B 0
#   * time         (time) datetime64[ns] 768B 2024-06-11 2024-06-14 ... 2025-05-30
# Data variables:
#     band_data    (time, band, y, x) float32 262MB 3.163e+03 ... 4.685e+03
