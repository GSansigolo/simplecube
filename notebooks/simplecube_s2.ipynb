# %%
import os
from simplecube import simple_cube

# %%
path_dir = os.path.abspath("")

# %%
cube=simple_cube(
    data_dir=os.path.join(path_dir),
    collection="S2_L2A-1",
    start_date="2024-01-01",
    end_date="2024-12-31",
    bbox="-46.7475,-15.8738,-46.6486,-15.7936",
    bands=["B08"]
)

cube
# Out:
# Downloading... : 100%|██████████| 73/73 [00:24<00:00,  3.04 itens/s]
# Successfully download 73 files to S2_L2A-1
# <xarray.Dataset> Size: 272MB
# Dimensions:      (band: 1, x: 1068, y: 897, time: 71)
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 9kB 3.128e+05 3.128e+05 ... 3.235e+05 3.235e+05
#   * y            (y) float64 7kB 8.253e+06 8.253e+06 ... 8.244e+06 8.244e+06
#     spatial_ref  int64 8B 0
#   * time         (time) datetime64[ns] 568B 2024-01-04 2024-01-09 ... 2024-12-29
# Data variables:
#     band_data    (time, band, y, x) float32 272MB 7.784e+03 ... 8.2e+03
